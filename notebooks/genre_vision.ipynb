# %%
import pandas as pd
import os
import datetime

# %%
#Select Directory Dataset
path = "D:/repos/projetos/video_game_sales/dataset"

#Change Directory Path
os.chdir(path)
print(os.getcwd())

#Show files in directory
files = os.listdir('.')
print(files)
# Out:
# D:\repos\projetos\video_game_sales\dataset
# ['indie_games_developers.csv', 'video_games_developers.csv', 'video_game_sales.csv']

# %%
#Load Indie Games and Video Games Developers

df_ig = pd.read_csv('indie_games_developers.csv')
df_ig = df_ig.loc[:,['Developer', 'Country']]
df_ig.columns = df_ig.columns.str.lower()

df_vg = pd.read_csv('video_games_developers.csv')
df_vg = df_vg.loc[:,['Developer', 'Country']]
df_vg.columns = df_vg.columns.str.lower()

#Merge datasets

df_dev = pd.concat([df_ig, df_vg],ignore_index = True)
df_dev

df_dev['country'] = df_dev['country'].str.replace(r'([a-z])([A-Z])', r'\1, \2', regex=True)
df_dev['country'] = df_dev['country'].replace({'Europe': 'France'})

#Tranform developer in snake_case to join in main dataset
df_dev['developer_sc'] = df_dev['developer'].str.lower().str.replace(' ','_').str.replace(' - ','_').str.replace('-','_').str.replace('.','')
df_dev['publisher_sc'] = df_dev['developer'].str.lower().str.replace(' ','_').str.replace(' - ','_').str.replace('-','_').str.replace('.','')
df_dev = df_dev.drop(columns = ['developer'])

df_dev
# Out:
#            country        developer_sc        publisher_sc
# 0           Poland      11_bit_studios      11_bit_studios
# 1            Chile            ace_team            ace_team
# 2    United States       akupara_games       akupara_games
# 3           Canada        alec_holowka        alec_holowka
# 4           Canada           alientrap           alientrap
# ..             ...                 ...                 ...
# 881        Hungary         zen_studios         zen_studios
# 882  United States  zipper_interactive  zipper_interactive
# 883  United States      zombie_studios      zombie_studios
# 884       Slovenia             zootfly             zootfly
# 885  United States               zynga               zynga
#
# [886 rows x 3 columns]

# %%
#Load Main File in Directory, show the type of columns and create a copy to original dataset

df = pd.read_csv('video_game_sales.csv')
print(df.dtypes)
df1 = df.copy()
# Out:
# img              object
# title            object
# console          object
# genre            object
# publisher        object
# developer        object
# critic_score    float64
# total_sales     float64
# na_sales        float64
# jp_sales        float64
# pal_sales       float64
# other_sales     float64
# release_date     object
# last_update      object
# dtype: object

# %%
#1. Creating the name_console; manufacture; generation, plataform and cycle life
console_name = {'PS3' : 'Playstation 3', 'PS4' : 'Playstation 4', 'PS2' : 'Playstation 2', 'X360' : 'Xbox 360', 'XOne' : 'Xbox One',
                'PC' : 'PC', 'PSP' : 'PSP', 'Wii' : 'Nintendo Wii', 'PS' : 'PlayStation', 'DS' : 'Nintendo DS', '2600' : 'Atari 2600', 
                'GBA' : 'GameBoy Advanced', 'NES': 'NES', 'XB' : 'Xbox', 'PSN' : 'Playstation Digital', 'GEN' : 'Sega Genesis', 
                'PSV' : 'PSVita', 'DC' : 'Sega DreamCast', 'N64' : 'Nintendo 64', 'SAT' : 'Sega Saturn', 'SNES' : 'Super Nintendo', 
                'GBC' : 'GameBoy Color', 'GC' : 'Nintendo GameCube', 'NS' : 'Nintendo Switch', '3DS': 'Nintendo 3DS', 
                'GB': 'Nintendo GameBoy', 'WiiU' : 'Nintendo WiiU', 'WS' : 'WonderSwan', 'VC' : 'Virtual Console Digital', 'NG':'NeoGeo', 
                'WW' : 'WiiWare Digital', 'SCD': 'Sega CD', 'PCE' : 'PC Engine', 'XBL': 'Xbox Live Digital', '3DO' : '3DO', 
                'GG' : 'Sega GameGear', 'OSX' : 'Apple PC OSX', 'Mob' : 'Mobile', 'PCFX' : 'PCFX', 'Series' : 'Xbox Series', 'All' : 'All', 
                'iOS': 'Apple iOS', '5200' :  'Atari 5200', 'And' : 'Android', 'DSiW': 'Nintendo DSi Digital', 'Lynx' : 'Atari Lynx',
                'Linux': 'Linux PC', 'MS' : 'Sega MasterSystem', 'ZXS' : 'ZX Spectrum', 'ACPC' : 'Amstrad CPC', 'Amig': 'Commodore Amiga',
                '7800' : 'Atari 7800', 'DSi' : 'Nintendo DS', 'AJ': 'Atari Jaguar', 'WinP': 'Windows Phone', 'iQue' : 'iQue Player',
                'GIZ': 'Gizmondo', 'VB': 'Nintendo VirtualBoy', 'Ouya': 'Ouya', 'NGage': 'Nokia NGage', 'AST': 'Atari ST PC', 'MSD':'MS-DOS',
                'S32X': 'Sega 32X', 'XS' : 'Xbox Series', 'PS5' : 'Playstation 5', 'Int': 'Intellivision', 'CV': 'ColecoVision', 
                'Arc': 'Arcade', 'C64': 'Commodore 64', 'FDS' : 'NES', 'MSX' : 'MSX', 'OR' : 'Oculus Rift', 'C128' : 'Commodore 128',
                'CDi': 'Philips CD Interactive', 'CD32' : 'Amiga CD32', 'BRW' : 'Web Browser Games', 'FMT' : 'FM Towns', 'ApII' : 'PC Apple II',
                'Aco': 'Acorn Archimedes', 'BBCM' : 'BBC Micro', 'TG16': 'PC Engine'}

df1['console_name'] = df['console'].map(console_name).fillna('Other/Unknown')

manufacture = {
    # Sony
    'PS': 'Sony', 'PS1': 'Sony', 'PS2': 'Sony', 'PS3': 'Sony', 'PS4': 'Sony', 'PS5': 'Sony', 
    'PSP': 'Sony', 'PSV': 'Sony', 'PSX': 'Sony', 'PSN': 'Sony',
    
    # Nintendo
    'NES': 'Nintendo', 'SNES': 'Nintendo', 'N64': 'Nintendo', 'GC': 'Nintendo', 'Wii': 'Nintendo', 
    'WiiU': 'Nintendo', 'Switch': 'Nintendo', 'NS': 'Nintendo', 'GB': 'Nintendo', 'GBA': 'Nintendo', 
    'GBC': 'Nintendo', 'DS': 'Nintendo', 'DSi': 'Nintendo', '3DS': 'Nintendo', 'VB': 'Nintendo', 
    'iQue': 'Nintendo', 'FDS': 'Nintendo', 'VC': 'Nintendo', 'DSiW': 'Nintendo',
    
    # Microsoft / PC
    'XB': 'Microsoft', 'X360': 'Microsoft', 'XOne': 'Microsoft', 'XS': 'Microsoft', 
    'XSX': 'Microsoft', 'XSS': 'Microsoft', 'Series': 'Microsoft', 'MSD': 'Microsoft', 
    'WinP': 'Microsoft', 'PC': 'PC/Other', 'Win': 'PC/Other', 'OSX': 'Apple', 'ApII': 'Apple', 
    
    # Sega
    'MS': 'Sega', 'GEN': 'Sega', 'MD': 'Sega', 'SAT': 'Sega', 'DC': 'Sega', 
    'GG': 'Sega', 'SCD': 'Sega', 'S32X': 'Sega',
    
    # Atari
    '2600': 'Atari', '5200': 'Atari', '7800': 'Atari', 'AJ': 'Atari', 'Lynx': 'Atari', 'AST': 'Atari',
    
    # Commodore
    'C64': 'Commodore', 'C128': 'Commodore', 'Amig': 'Commodore', 'CD32': 'Commodore', 'VIC20': 'Commodore',
    
    # Outros
    'PCE': 'NEC', 'TG16': 'NEC', 'PCFX': 'NEC', 'WS': 'Bandai', 'WSC': 'Bandai',
    '3DO': 'Panasonic', 'CDi': 'Philips', 'Int': 'Mattel', 'CV': 'Coleco',
    'FMT': 'Fujitsu', 'Aco': 'Acorn', 'BBCM': 'Acorn', 'GIZ': 'Tiger', 'Ouya': 'Ouya',
    'Arc': 'Arcade', 'Mob': 'Mobile', 'And': 'Mobile', 'iOS': 'Mobile', 'BRW': 'Web',
    'OR': 'Oculus/Meta', 'NG': 'SNK', 'NEO': 'SNK', 'NGP': 'SNK'
}

df1['manufacture'] = df['console'].map(manufacture).fillna('Other/Unknown')

gen_mapping = {
    '2600': '2nd Gen', '5200': '2nd Gen', 'Int': '2nd Gen', 'CV': '2nd Gen', 
    'NES': '3rd Gen', 'MS': '3rd Gen', '7800': '3rd Gen', 'GG': '3rd Gen', 'FDS': '3rd Gen', 'MSX': '3rd Gen',
    'SNES': '4th Gen', 'GEN': '4th Gen', 'MD': '4th Gen', 'GB': '4th Gen', 'TG16': '4th Gen', 'NG': '4th Gen', 'SCD': '4th Gen',
    'PCE': '4th Gen', 'Lynx': '4th Gen', 'S32X': '4th Gen',
    'PS': '5th Gen', 'PS1': '5th Gen', 'N64': '5th Gen', 'SAT': '5th Gen', 'AJ': '5th Gen', 'GBC': '5th Gen', '3DO': '5th Gen',
    'PCFX': '5th Gen', 'VB': '5th Gen',
    'PS2': '6th Gen', 'XB': '6th Gen', 'GC': '6th Gen', 'DC': '6th Gen', 'GBA': '6th Gen', 'WS': '6th Gen', 'iQue': '6th Gen',
    'NGage': '6th Gen',
    'PS3': '7th Gen', 'X360': '7th Gen', 'Wii': '7th Gen', 'DS': '7th Gen', 'PSP': '7th Gen', 'DSi': '7th Gen', 'GIZ': '7th Gen',
    'PS4': '8th Gen', 'XOne': '8th Gen', 'WiiU': '8th Gen', 'NS': '8th Gen', '3DS': '8th Gen', 'PSV': '8th Gen', 'Ouya': '8th Gen',
    'PS5': '9th Gen', 'XS': '9th Gen', 'Series': '9th Gen'
}

df1['generation'] = df['console'].map(gen_mapping).fillna('Other/Unknown')

plataform = {
    #PC
    'PC': 'PC', 'OSX': 'PC', 'Linux': 'PC', 'ZXS': 'PC', 'ACPC': 'PC', 'Amig': 'PC', 
    'AST': 'PC', 'MSX': 'PC', 'C64': 'PC', 'C128':'PC', 'FMT': 'PC', 'ApII': 'PC', 'Aco' :'PC', 'BBCM': 'PC',
    #Mobile
    'Mob': 'Mobile', 'iOS': 'Mobile', 'And': 'Mobile', 'WinP': 'Mobile',
    #Digital Service
   'PSN' : 'Digital Service', 'XBL': 'Digital Service', 'VC' : 'Digital Service', 'WW' : 'Digital Service', 
   'DSiW' : 'Digital Service', 'BRW':'Digital Service'
}

df1['plataform'] = df1['console'].map(plataform).fillna('Console')

portable = {
    'PSP': 'Yes', 'DS': 'Yes', 'DSi': 'Yes', 'GBA': 'Yes', 'PSV': 'Yes', 'GBC': 'Yes', 'NS': 'Yes',
    '3DS': 'Yes', 'GB': 'Yes', 'WS': 'Yes', 'GG': 'Yes', 'Lynx': 'Yes', 'GIZ': 'Yes', 'VB' : 'Yes'
}

df1['portable'] = df1['console'].map(portable).fillna('No')

actual_year = 2026
consoles_cycle_life = {
    'PS3': [2006, 2017], 'PS4': [2013, None], 'PS2': [2000, 2013], 
    'X360': [2005, 2016], 'XOne': [2013, None], 'PC': [1985, None], 
    'PSP': [2004, 2014], 'Wii': [2006, 2013], 'PS': [1994, 2004], 
    'DS': [2004, 2013], '2600': [1977, 1992], 'GBA': [2001, 2008], 
    'NES': [1983, 1995], 'XB': [2001, 2009], 'PSN': [2006, None], 
    'GEN': [1988, 1998], 'PSV': [2011, 2019], 'DC': [1998, 2001], 
    'N64': [1996, 2002], 'SAT': [1994, 2000], 'SNES': [1990, 2003], 
    'GBC': [1998, 2003], 'GC': [2001, 2007], 'NS': [2017, None], 
    '3DS': [2011, 2020], 'GB': [1989, 2003], 'WiiU': [2012, 2017], 
    'WS': [1999, 2003], 'VC': [2006, 2019], 'NG': [1990, 2004], 
    'WW': [2008, 2019], 'SCD': [1991, 1996], 'PCE': [1987, 1994], 
    'XBL': [2002, None], '3DO': [1993, 1996], 'GG': [1990, 1997], 
    'OSX': [2001, None], 'Mob': [2008, None], 'PCFX': [1994, 1998], 
    'Series': [2020, None], 'iOS': [2008, None], '5200': [1982, 1984], 
    'And': [2008, None], 'DSiW': [2008, 2017], 'Lynx': [1989, 1995], 
    'Linux': [1991, None], 'MS': [1985, 1992], 'ZXS': [1982, 1992], 
    'ACPC': [1984, 1990], 'Amig': [1985, 1996], '7800': [1986, 1991], 
    'DSi': [2008, 2013], 'AJ': [1993, 1996], 'WinP': [2010, 2019], 
    'iQue': [2003, 2018], 'GIZ': [2005, 2006], 'VB': [1995, 1996], 
    'Ouya': [2013, 2015], 'NGage': [2003, 2005], 'AST': [1985, 1993], 
    'MSD': [1981, 2000], 'S32X': [1994, 1996], 'XS': [2020, None], 
    'PS5': [2020, None], 'Int': [1979, 1991], 'CV': [1982, 1985], 
    'Arc': [1971, None], 'C64': [1982, 1994], 'FDS': [1986, 2003], 
    'MSX': [1983, 1995], 'OR': [2016, None], 'C128': [1985, 1989], 
    'CDi': [1991, 1998], 'CD32': [1993, 1994], 'BRW': [1995, None], 
    'FMT': [1989, 1997], 'ApII': [1977, 1993], 'Aco': [1987, 1992], 
    'BBCM': [1981, 1994], 'TG16': [1987, 1994]
}

df_ref = pd.DataFrame.from_dict(consoles_cycle_life, orient = 'index', columns = ['start_year', 'end_year'])
df_ref['end_year'] = df_ref['end_year'].fillna(actual_year)
df_ref['activity_years'] = df_ref['end_year'] - df_ref['start_year']
df_ref['activity_years'] = df_ref['activity_years'].replace(0,1)

df1 = df1.merge(df_ref[['start_year','end_year','activity_years',]], 
                left_on = 'console', 
                right_index=True, 
                how='left')

#2.Merge links (domain + url chart game)

domain = "https://vgchartz.com"

df1['url_chart'] = domain + df1['img']

#3. Format date

df1['release_date'] = pd.to_datetime(df['release_date']).dt.date

#4. Merge developer country

df1['developer_sc'] = df1['developer'].str.lower().str.replace(' ','_').str.replace(' ',' - ').str.replace('-','_').str.replace('.','')
df1 = pd.merge(df1, df_dev, on='developer_sc', how = 'left')
df1 = df1.rename(columns={'country' : 'country_developer'})

df1['publisher_sc'] = df1['publisher'].str.lower().str.replace(' ','_').str.replace(' ',' - ').str.replace('-','_').str.replace('.','')
df1 = pd.merge(df1, df_dev, on='publisher_sc', how = 'left')
df1 = df1.rename(columns={'country' : 'country_publisher'})

#5. Drop columns and finish clean dataset
df1 = df1.drop(columns = ['img', 'developer_sc_x', 'publisher_sc', 'developer_sc_y', 'last_update'])

#6.Verification the space before or after the sentence
for col in df1.select_dtypes(include='object').columns:
    try:
        df1[col] = df1[col].str.strip()
    except AttributeError:
        pass

#7.Insert qualify column into dataset

df1['classification'] = pd.cut(
    df1['critic_score'],
    bins=[-float('inf'), 5.0, 7.0, 9.0, float('inf')],
    labels=['Bad', 'Regular', 'Good', 'Premium']
).cat.add_categories('Unrated').fillna('Unrated')

#8. Correction Similar Developers and Publishers Country
corrections_country = {
    'United Kingdom (England)' : 'England',
    'United Kingdom' : 'England',
    'Austria, Sweden' : 'Austria',
    'Ukraine, Malta': 'Ukraine',
    'United States, Canada': 'United States'
}

df1['country_publisher'] = df1['country_publisher'].replace(corrections_country)
df1['country_developer'] = df1['country_developer'].replace(corrections_country)

#9. Correction Similar Developers and Publishers
name_correction = {
    'Square-Enix': 'Square Enix',
    'Milestone S.r.l': 'Milestone S.r.l.',
    'Humongous Entertainment.': 'Humongous Entertainment',
    'Flight-Plan': 'Flight Plan'
}

df1['publisher'] = df1['publisher'].replace(name_correction)
df1['developer'] = df1['developer'].replace(name_correction)

print(df1.dtypes)
df1
# Out:
# title                  object
# console                object
# genre                  object
# publisher              object
# developer              object
# critic_score          float64
# total_sales           float64
# na_sales              float64
# jp_sales              float64
# pal_sales             float64
# other_sales           float64
# release_date           object
# console_name           object
# manufacture            object
# generation             object
# plataform              object
# portable               object
# start_year            float64
# end_year              float64
# activity_years        float64
# url_chart              object
# country_developer      object
# country_publisher      object
# classifiction        category
# dtype: object
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# ...

# %%
# Performance por Gênero
#P: O CEO precisa decidir em quais departamentos de criação (estúdios especializados) a empresa deve investir
# identificar os extremos de qualidade. Gêneros com notas consistentemente baixas podem indicar saturação ou falta de inovação, 
# enquanto gêneros com notas altas e vendas baixas podem indicar oportunidades de nicho mal exploradas.

filter_by_sales = df1[df1['total_sales'] >= 0.1].dropna(subset='critic_score')

#1.Dos títulos que possuem o gênero "Action", qual o nome do jogo com a maior média de Critic Score?

action_best_critic_score = (
    filter_by_sales[filter_by_sales['genre'] == 'Action'].groupby(['title'])['critic_score']
    .mean()
    .sort_values (ascending = False)
    .reset_index (name = 'critic_score')
    .round(2)
)

best_title_action_name = action_best_critic_score['title'].iloc[0]
best_title_action_score = action_best_critic_score['critic_score'].iloc[0]

print(f'O do jogo com a maior média de Critic Score do genero Action é: {best_title_action_name} com nota média - {best_title_action_score}')

#2.Dos títulos que possuem o gênero "Action", qual o nome do jogo com a menor média de Critic Score? (Filtrar por titulos acima de 100k)

action_worst_critic_score = (
    filter_by_sales[filter_by_sales['genre'] == 'Action'].groupby(['title'])['critic_score']
    .mean()
    .sort_values (ascending = True)
    .reset_index (name = 'critic_score')
    .round(2)
)

worst_title_action_name = action_worst_critic_score['title'].iloc[0]
worst_title_action_score = action_worst_critic_score['critic_score'].iloc[0]

print(f'O do jogo com a menor média de Critic Score do genero Action é: {worst_title_action_name} com nota média - {worst_title_action_score}')

#3.Dos títulos que possuem o gênero "Sports", qual o nome do jogo com a maior média de Critic Score?

sports_best_critic_score =(
    filter_by_sales[filter_by_sales['genre'] == 'Sports'].groupby(['title'])['critic_score']
    .mean()
    .sort_values (ascending = False)
    .reset_index (name = 'critic_score')
    .round(2)
)

best_title_sports_name = sports_best_critic_score['title'].iloc[0]
best_title_sports_score = sports_best_critic_score['critic_score'].iloc[0]

print(f'O do jogo com a maior média de Critic Score do genero Sports é: {best_title_sports_name} com nota média - {best_title_sports_score}')

#4.Dos títulos que possuem o gênero "Sports", qual o nome do jogo com a menor média de Critic Score? (Filtrar por titulos acima de 100k)

sports_worst_critic_score =(
    filter_by_sales[filter_by_sales['genre'] == 'Sports'].groupby(['title'])['critic_score']
    .mean()
    .sort_values (ascending = True)
    .reset_index (name = 'critic_score')
    .round(2)
)

worst_title_sports_name = sports_worst_critic_score['title'].iloc[0]
worst_title_sports_score = sports_worst_critic_score['critic_score'].iloc[0]

print(f'O do jogo com a menor média de Critic Score do genero Sports é: {worst_title_sports_name} com nota média - {worst_title_sports_score}')

#5.Dos títulos que possuem o gênero "Role-Playing" (RPG), qual o nome do jogo com a maior média de Critic Score?

rpg_best_critic_score =(
    filter_by_sales[filter_by_sales['genre'] == 'Role-Playing'].groupby(['title'])['critic_score']
    .mean()
    .sort_values (ascending = False)
    .reset_index (name = 'critic_score')
    .round(2)
)

best_title_rpg_name = rpg_best_critic_score['title'].iloc[0]
best_title_rpg_score = rpg_best_critic_score['critic_score'].iloc[0]

print(f'O do jogo com a maior média de Critic Score do genero RPG é: {best_title_rpg_name} com nota média - {best_title_rpg_score}')

#6. Dos títulos que possuem o gênero "Role-Playing" (RPG), qual o nome do jogo com a menor média de Critic Score? (Filtrar por titulos acima de 100k)

rpg_worst_critic_score = (
    filter_by_sales[filter_by_sales['genre'] == 'Role-Playing'].groupby(['title'])['critic_score']
    .mean()
    .sort_values (ascending = True)
    .reset_index (name = 'critic_score')
    .round(2)
)

worst_title_rpg_name = rpg_worst_critic_score['title'].iloc[0]
worst_title_rpg_score = rpg_worst_critic_score['critic_score'].iloc[0]

print(f'O do jogo com a menor média de Critic Score do genero RPG é: {worst_title_rpg_name} com nota média - {worst_title_rpg_score}')

#7.Dos títulos que possuem o gênero "Shooter", qual o nome do jogo com a maior média de Critic Score?

shooter_best_critic_score = (
    filter_by_sales[filter_by_sales['genre'] == 'Shooter'].groupby(['title'])['critic_score']
    .mean()
    .sort_values (ascending = False)
    .reset_index (name = 'critic_score')
    .round(2)
)

best_title_shooter_name = shooter_best_critic_score['title'].iloc[0]
best_title_shooter_score = shooter_best_critic_score['critic_score'].iloc[0]

print(f'O do jogo com a maior média de Critic Score do genero Shooter é: {best_title_shooter_name} com nota média - {best_title_shooter_score}')

#8.Dos títulos que possuem o gênero "Shooter", qual o nome do jogo com a menor média de Critic Score? (Filtrar por titulos acima de 100k)

shooter_worst_critic_score = (
    filter_by_sales[filter_by_sales['genre'] == 'Shooter'].groupby(['title'])['critic_score']
    .mean()
    .sort_values (ascending = True)
    .reset_index (name = 'critic_score')
    .round(2)
)

worst_title_shooter_name = shooter_worst_critic_score['title'].iloc[0]
worst_title_shooter_score = shooter_worst_critic_score['critic_score'].iloc[0]

print(f'O do jogo com a menor média de Critic Score do genero Shooter é: {worst_title_shooter_name} com nota média - {worst_title_shooter_score}')

#9. Dos títulos que possuem o gênero "Simulation", qual o nome do jogo com a maior média de Critic Score?

simulation_best_critic_score =(
    filter_by_sales[filter_by_sales['genre'] == 'Simulation'].groupby(['title'])['critic_score']
    .mean()
    .sort_values(ascending = False)
    .reset_index (name = 'critic_score')
    .round(2)
)

best_title_simulation_name = simulation_best_critic_score['title'].iloc[0]
best_title_simulation_score = simulation_best_critic_score['critic_score'].iloc[0]

print(f'O do jogo com a maior média de Critic Score do genero Simulation é: {best_title_simulation_name} com nota média - {best_title_simulation_score}')

#10. Dos títulos que possuem o gênero "Simulation", qual o nome do jogo com a menor média de Critic Score? (Filtrar por titulos acima de 100k)

simulation_worst_critic_score = (
    filter_by_sales[filter_by_sales['genre'] == 'Simulation'].groupby(['title'])['critic_score']
    .mean()
    .sort_values(ascending = True)
    .reset_index (name = 'critic_score')
    .round(2)
)

worst_title_simulation_name = simulation_worst_critic_score['title'].iloc[0]
worst_title_simulation_score = simulation_worst_critic_score['critic_score'].iloc[0]

print(f'O do jogo com a menor média de Critic Score do genero Simulation é: {worst_title_simulation_name} com nota média - {worst_title_simulation_score}')

#11. Qual o tipo de Gênero que possui o maior valor medio de vendas globais por título? (filtrar por quantidade de lançamentos)

global_sales_genre_mean = (
    filter_by_sales.groupby('genre')
    .agg(
        total_sales = ('total_sales', 'mean'),
        lancamentos = ('title', 'nunique')
    )
    .sort_values ('total_sales', ascending = False)
    .reset_index ()
    .round(2)
)

global_sales_genre_mean_filter = global_sales_genre_mean[global_sales_genre_mean['lancamentos'] >= 10]

best_genre_type = global_sales_genre_mean_filter['genre'].iloc[0]
best_genre_sales = global_sales_genre_mean_filter['total_sales'].iloc[0]

print(f'O genero que possui maior valor médio de vendas globais é {best_genre_type} com {best_genre_sales} milhoes de copias vendidas')

#12. Qual o tipo de Gênero que possui a maior média de Critic Score entre todos os seus lançamentos? (filtrar por quantidade de lançamentos)

genre_critic_score_mean = (
    filter_by_sales.groupby ('genre')
    .agg(
        critic_score = ('critic_score', 'mean'),
        lancamentos = ('title', 'nunique')
    )
    .sort_values ('critic_score', ascending = False)
    .reset_index()
    .round(2)
)

genre_critic_score_mean_filter = genre_critic_score_mean[genre_critic_score_mean['lancamentos'] >= 10]

best_genre_critic_title = genre_critic_score_mean_filter['genre'].iloc[0]
best_genre_critic_score = genre_critic_score_mean_filter['critic_score'].iloc[0]

print(f'O gênero que possui a maior média de Critic Score entre todos os seus lançamentos é {best_genre_critic_title} com nota média de {best_genre_critic_score}')

#13. Qual o tipo de Gênero que possui mais títulos com vendas registradas em todas as três principais regiões (NA, JP e PAL)?

regions = {'NA': 'na_sales', 'JP':'jp_sales', 'PAL': 'pal_sales', 'Other': 'other_sales'}

results = []

for region, col in regions.items():
    #Titulo mais vendido por genero
    top_title_per_genre = (
        df1.groupby(['genre', 'title'])[col]
        .sum()
        .reset_index()
        .sort_values(col, ascending = False)
        .groupby('genre')
        .first()
        .reset_index()
        .rename(columns={'title': 'top_title'})
    )

    #Total de Vendas por Genero
    sales_genre = (
        df1.groupby('genre')[col]
        .sum()
        .reset_index(name='total_sales')
        .merge(top_title_per_genre[['genre','top_title']], on='genre')
        .sort_values('total_sales', ascending = False)
    )
    
    #Armazenamento do Resultado
    results.append({
        'region' : region,
        'genre' : sales_genre.iloc[0]['genre'],
        'total_sales' : sales_genre.iloc[0]['total_sales'],
        'top_title' : sales_genre.iloc[0]['top_title']
    })

best_sales_per_region = pd.DataFrame (results)
best_sales_per_region

#14. Qual o tipo de gênero mais vendido no mundo por geração ?

ajust_generation = df1[(df1['generation'] != 'Other/Unknown') & (df1['generation'] != '9th Gen')]

sales_gen_global_sales = (
    ajust_generation.groupby(['genre', 'generation'])
    .agg(
        total_sales = ('total_sales', 'sum'),
        lancamentos = ('title', 'nunique')
    )
    .sort_values('total_sales', ascending = False)
    .reset_index()
    .round(2)
)

sales_gen_global_sales_filter = sales_gen_global_sales[sales_gen_global_sales['lancamentos'] >= 1]
best_genre_per_gen = sales_gen_global_sales_filter.groupby('generation').first().reset_index()

print(best_genre_per_gen)

#15. Qual o tipo a maior média de Critic Score por genero em cada geração ?

critic_score_per_genre_gen = (
    filter_by_sales.groupby(['genre', 'generation'])['critic_score']
    .mean()
    .sort_values(ascending = False)
    .reset_index()
    .round(2)
)

best_critic_score_per_gen = critic_score_per_genre_gen.groupby('generation').first().reset_index()
print(best_critic_score_per_gen)
# Out:
# O do jogo com a maior média de Critic Score do genero Action é: Red Dead Redemption: Undead Nightmare com nota média - 10.0
# O do jogo com a menor média de Critic Score do genero Action é: Spawn the Eternal com nota média - 1.9
# O do jogo com a maior média de Critic Score do genero Sports é: NFL 2K com nota média - 9.7
# O do jogo com a menor média de Critic Score do genero Sports é: DECA Sports Freedom com nota média - 3.0
# O do jogo com a maior média de Critic Score do genero RPG é: South Park: The Fractured But Whole com nota média - 9.5
# O do jogo com a menor média de Critic Score do genero RPG é: Mana Khemia: Student Alliance com nota média - 3.2
# O do jogo com a maior média de Critic Score do genero Shooter é: Portal 2 com nota média - 9.6
# O do jogo com a menor média de Critic Score do genero Shooter é: Rogue Warrior com nota média - 2.75
# O do jogo com a maior média de Critic Score do genero Simulation é: Star Wars Rogue Leader: Rogue Squadron II com nota média - 9.2
# ...
